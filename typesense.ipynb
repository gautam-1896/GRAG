# %% [markdown]
# RAG Application Using Type Sense

# %% [markdown]
# import typesense

# %%
import typesense

# %%
client = typesense.Client({
    'nodes': [{
        'host': 'd5ai23oclq4xzt9fp-1.a1.typesense.net',
        'port': '443',
        'protocol': 'https'
    }],
    'api_key': 'vE8Yd1k8dmlz1LEVOj8OdfRMsrwe42CF',
    'connection_timeout_seconds': 10
})
books_schema = {
    'name': 'books',
    'fields': [
        {'name': 'title', 'type': 'string'},
        {'name': 'authors', 'type': 'string[]', 'facet': True},
        {'name': 'publication_year', 'type': 'int32', 'facet': True},
        {'name': 'ratings_count', 'type': 'int32'},
        {'name': 'average_rating', 'type': 'float'}
    ],
    'default_sorting_field': 'ratings_count'
}

print(client.collections.create(books_schema))
# Out:
# {'created_at': 1781274072, 'curation_sets': [], 'default_sorting_field': 'ratings_count', 'enable_nested_fields': False, 'fields': [{'facet': False, 'index': True, 'infix': False, 'locale': '', 'name': 'title', 'optional': False, 'sort': False, 'stem': False, 'stem_dictionary': '', 'store': True, 'truncate_len': 100, 'type': 'string'}, {'facet': True, 'index': True, 'infix': False, 'locale': '', 'name': 'authors', 'optional': False, 'sort': False, 'stem': False, 'stem_dictionary': '', 'store': True, 'truncate_len': 100, 'type': 'string[]'}, {'facet': True, 'index': True, 'infix': False, 'locale': '', 'name': 'publication_year', 'optional': False, 'sort': True, 'stem': False, 'stem_dictionary': '', 'store': True, 'truncate_len': 100, 'type': 'int32'}, {'facet': False, 'index': True, 'infix': False, 'locale': '', 'name': 'ratings_count', 'optional': False, 'sort': True, 'stem': False, 'stem_dictionary': '', 'store': True, 'truncate_len': 100, 'type': 'int32'}, {'facet': False, 'index': True, 'infix': False, 'locale': '', 'name': 'average_rating', 'optional': False, 'sort': True, 'stem': False, 'stem_dictionary': '', 'store': True, 'truncate_len': 100, 'type': 'float'}], 'name': 'books', 'num_documents': 0, 'symbols_to_index': [], 'synonym_sets': [], 'token_separators': []}

# %%
client

# %%
with open('books.jsonl', 'r', encoding='utf-8') as jsonl_file:
    data = jsonl_file.read()
    client.collections['books'].documents.import_(data)

# %%
search_parameters={
    'q':"harry potter",
    'query_by':"title,authors",
    'sort_by':"ratings_count:desc"
}

client.collections['books'].documents.search(search_parameters)
# Out:
# {'facet_counts': [],
#  'found': 17,
#  'hits': [{'document': {'authors': ['J.K. Rowling', ' Mary GrandPré'],
#     'average_rating': 4.44,
#     'id': '2',
#     'image_url': 'https://images.gr-assets.com/books/1474154022m/3.jpg',
#     'publication_year': 1997,
#     'ratings_count': 4602479,
#     'title': "Harry Potter and the Philosopher's Stone"},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': "<mark>Harry</mark> <mark>Potter</mark> and the Philosopher's Stone"}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': "<mark>Harry</mark> <mark>Potter</mark> and the Philosopher's Stone"}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}},
#   {'document': {'authors': ['J.K. Rowling', ' Mary GrandPré', ' Rufus Beck'],
#     'average_rating': 4.53,
#     'id': '18',
#     'image_url': 'https://images.gr-assets.com/books/1499277281m/5.jpg',
#     'publication_year': 1999,
#     'ratings_count': 1832823,
#     'title': 'Harry Potter and the Prisoner of Azkaban'},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Prisoner of Azkaban'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Prisoner of Azkaban'}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}},
#   {'document': {'authors': ['J.K. Rowling', ' Mary GrandPré'],
#     'average_rating': 4.37,
#     'id': '23',
#     'image_url': 'https://images.gr-assets.com/books/1474169725m/15881.jpg',
#     'publication_year': 1998,
#     'ratings_count': 1779331,
#     'title': 'Harry Potter and the Chamber of Secrets'},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Chamber of Secrets'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Chamber of Secrets'}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}},
#   {'document': {'authors': ['J.K. Rowling', ' Mary GrandPré'],
#     'average_rating': 4.53,
#     'id': '24',
#     'image_url': 'https://images.gr-assets.com/books/1361482611m/6.jpg',
#     'publication_year': 2000,
#     'ratings_count': 1753043,
#     'title': 'Harry Potter and the Goblet of Fire'},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Goblet of Fire'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Goblet of Fire'}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}},
#   {'document': {'authors': ['J.K. Rowling', ' Mary GrandPré'],
#     'average_rating': 4.61,
#     'id': '25',
#     'image_url': 'https://images.gr-assets.com/books/1474171184m/136251.jpg',
#     'publication_year': 2007,
#     'ratings_count': 1746574,
#     'title': 'Harry Potter and the Deathly Hallows'},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Deathly Hallows'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Deathly Hallows'}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}},
#   {'document': {'authors': ['J.K. Rowling', ' Mary GrandPré'],
#     'average_rating': 4.46,
#     'id': '21',
#     'image_url': 'https://images.gr-assets.com/books/1387141547m/2.jpg',
#     'publication_year': 2003,
#     'ratings_count': 1735368,
#     'title': 'Harry Potter and the Order of the Phoenix'},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Order of the Phoenix'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Order of the Phoenix'}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}},
#   {'document': {'authors': ['J.K. Rowling', ' Mary GrandPré'],
#     'average_rating': 4.54,
#     'id': '27',
#     'image_url': 'https://images.gr-assets.com/books/1361039191m/1.jpg',
#     'publication_year': 2005,
#     'ratings_count': 1678823,
#     'title': 'Harry Potter and the Half-Blood Prince'},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Half-Blood Prince'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Half-Blood Prince'}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}},
#   {'document': {'authors': ['John Tiffany', ' Jack Thorne', ' J.K. Rowling'],
#     'average_rating': 3.75,
#     'id': '279',
#     'image_url': 'https://images.gr-assets.com/books/1470082995m/29056083.jpg',
#     'publication_year': 2016,
#     'ratings_count': 270603,
#     'title': 'Harry Potter and the Cursed Child, Parts One and Two'},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Cursed Child, Parts One and Two'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark> and the Cursed Child, Parts One and Two'}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}},
#   {'document': {'authors': ['J.K. Rowling'],
#     'average_rating': 4.74,
#     'id': '422',
#     'image_url': 'https://images.gr-assets.com/books/1392579059m/862041.jpg',
#     'publication_year': 1998,
#     'ratings_count': 190050,
#     'title': 'Complete Harry Potter Boxed Set'},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': 'Complete <mark>Harry</mark> <mark>Potter</mark> Boxed Set'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': 'Complete <mark>Harry</mark> <mark>Potter</mark> Boxed Set'}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}},
#   {'document': {'authors': ['Brian Sibley'],
#     'average_rating': 4.48,
#     'id': '2001',
#     'image_url': 'https://images.gr-assets.com/books/1464452934m/7952502.jpg',
#     'publication_year': 2010,
#     'ratings_count': 45081,
#     'title': 'Harry Potter: Film Wizardry'},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark>: Film Wizardry'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': '<mark>Harry</mark> <mark>Potter</mark>: Film Wizardry'}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}}],
#  'out_of': 9979,
#  'page': 1,
#  'request_params': {'collection_name': 'books',
#   'first_q': 'harry potter',
#   'per_page': 10,
#   'q': 'harry potter'},
#  'search_cutoff': False,
#  'search_time_ms': 5}

# %%
search_parameters = {
  'q'         : 'harry potter',
  'query_by'  : 'title',
  'filter_by' : 'publication_year:<1998',
  'sort_by'   : 'publication_year:desc'
}

client.collections['books'].documents.search(search_parameters)
# Out:
# {'facet_counts': [],
#  'found': 1,
#  'hits': [{'document': {'authors': ['J.K. Rowling', ' Mary GrandPré'],
#     'average_rating': 4.44,
#     'id': '2',
#     'image_url': 'https://images.gr-assets.com/books/1474154022m/3.jpg',
#     'publication_year': 1997,
#     'ratings_count': 4602479,
#     'title': "Harry Potter and the Philosopher's Stone"},
#    'highlight': {'title': {'matched_tokens': ['Harry', 'Potter'],
#      'snippet': "<mark>Harry</mark> <mark>Potter</mark> and the Philosopher's Stone"}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Harry', 'Potter'],
#      'snippet': "<mark>Harry</mark> <mark>Potter</mark> and the Philosopher's Stone"}],
#    'text_match': 1157451471441102969,
#    'text_match_info': {'best_field_score': '2211897868289',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '1157451471441102969',
#     'tokens_matched': 2,
#     'typo_prefix_score': 0}}],
#  'out_of': 9979,
#  'page': 1,
#  'request_params': {'collection_name': 'books',
#   'first_q': 'harry potter',
#   'per_page': 10,
#   'q': 'harry potter'},
#  'search_cutoff': False,
#  'search_time_ms': 0}

# %%
search_parameters = {
  'q'         : 'experyment',
  'query_by'  : 'title',
  'facet_by'  : 'authors',
  'sort_by'   : 'average_rating:desc'
}

client.collections['books'].documents.search(search_parameters)
# Out:
# {'facet_counts': [{'counts': [{'count': 1,
#      'highlighted': ' Käthe Mazur',
#      'value': ' Käthe Mazur'},
#     {'count': 1, 'highlighted': 'Mahatma Gandhi', 'value': 'Mahatma Gandhi'},
#     {'count': 1, 'highlighted': 'Gretchen Rubin', 'value': 'Gretchen Rubin'},
#     {'count': 1,
#      'highlighted': 'James Patterson',
#      'value': 'James Patterson'}],
#    'field_name': 'authors',
#    'sampled': False,
#    'stats': {'total_values': 4}}],
#  'found': 3,
#  'hits': [{'document': {'authors': ['James Patterson'],
#     'average_rating': 4.08,
#     'id': '569',
#     'image_url': 'https://images.gr-assets.com/books/1339277875m/13152.jpg',
#     'publication_year': 2005,
#     'ratings_count': 172302,
#     'title': 'The Angel Experiment'},
#    'highlight': {'title': {'matched_tokens': ['Experiment'],
#      'snippet': 'The Angel <mark>Experiment</mark>'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Experiment'],
#      'snippet': 'The Angel <mark>Experiment</mark>'}],
#    'text_match': 578730054645713017,
#    'text_match_info': {'best_field_score': '1108057784321',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '578730054645713017',
#     'tokens_matched': 1,
#     'typo_prefix_score': 2}},
#   {'document': {'authors': ['Mahatma Gandhi'],
#     'average_rating': 4.07,
#     'id': '2649',
#     'image_url': 'https://images.gr-assets.com/books/1320560971m/112803.jpg',
#     'publication_year': 1940,
#     'ratings_count': 28177,
#     'title': 'An Autobiography or The Story of My Experiments with Truth'},
#    'highlight': {'title': {'matched_tokens': ['Experiments'],
#      'snippet': 'An Autobiography or The Story of My <mark>Experiments</mark> with Truth'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Experiments'],
#      'snippet': 'An Autobiography or The Story of My <mark>Experiments</mark> with Truth'}],
#    'text_match': 578730054645713017,
#    'text_match_info': {'best_field_score': '1108057784321',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '578730054645713017',
#     'tokens_matched': 1,
#     'typo_prefix_score': 2}},
#   {'document': {'authors': ['Gretchen Rubin', ' Käthe Mazur'],
#     'average_rating': 3.48,
#     'id': '9718',
#     'image_url': 'https://images.gr-assets.com/books/1344014249m/13414599.jpg',
#     'publication_year': 2012,
#     'ratings_count': 6058,
#     'title': 'Happier at Home: Kiss More, Jump More, Abandon a Project, Read Samuel Johnson, and My Other Experiments in the Practice of Everyday Life'},
#    'highlight': {'title': {'matched_tokens': ['Experiments'],
#      'snippet': 'Happier at Home: Kiss More, Jump More, Abandon a Project, Read Samuel Johnson, and My Other <mark>Experiments</mark> in the Practice of Everyday Life'}},
#    'highlights': [{'field': 'title',
#      'matched_tokens': ['Experiments'],
#      'snippet': 'Happier at Home: Kiss More, Jump More, Abandon a Project, Read Samuel Johnson, and My Other <mark>Experiments</mark> in the Practice of Everyday Life'}],
#    'text_match': 578730054645713017,
#    'text_match_info': {'best_field_score': '1108057784321',
#     'best_field_weight': 15,
#     'fields_matched': 1,
#     'num_tokens_dropped': 0,
#     'score': '578730054645713017',
#     'tokens_matched': 1,
#     'typo_prefix_score': 2}}],
#  'out_of': 9979,
#  'page': 1,
#  'request_params': {'collection_name': 'books',
#   'first_q': '',
#   'per_page': 10,
#   'q': 'experyment'},
#  'search_cutoff': False,
#  'search_time_ms': 1}

# %%
### Langchain + Typsense + Groq LLM + RAG Application

from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Typesense
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_groq import ChatGroq

# %%
import os
os.environ["GROQ_API_KEY"] = "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"

# %%
loader = TextLoader("test.txt")
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
docs = text_splitter.split_documents(documents)

embeddings = HuggingFaceEmbeddings()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File d:\YTRAG\.venv\Lib\site-packages\langchain_community\document_loaders\text.py:42, in TextLoader.lazy_load(self)
#      41 try:
# ---> 42     with open(self.file_path, encoding=self.encoding) as f:
#      43         text = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 2
#       1 loader = TextLoader("test.txt")
# ----> 2 documents = loader.load()
#       3 text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
#       4 docs = text_splitter.split_documents(documents)
#       5
#
# File d:\YTRAG\.venv\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File d:\YTRAG\.venv\Lib\site-packages\langchain_community\document_loaders\text.py:58, in TextLoader.lazy_load(self)
#      56         raise RuntimeError(f"Error loading {self.file_path}") from e
#      57 except Exception as e:
# ---> 58     raise RuntimeError(f"Error loading {self.file_path}") from e
#      60 metadata = {"source": str(self.file_path)}
#      61 yield Document(page_content=text, metadata=metadata)
#
# RuntimeError: Error loading test.txt

# %%
from langchain_core.documents import Document
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Typesense

# 1. Create docs
docs = [
    Document(page_content="Typesense is a fast search engine."),
    Document(page_content="LangChain helps build AI apps.")
]

# 2. Create embeddings
embeddings = OpenAIEmbeddings()

# 3. Create vector store
docsearch = Typesense.from_documents(
    docs,
    embeddings,
    typesense_client_params={
        "host": "8a5wnxyt2pmjdoh9p-1.a1.typesense.net",
        "port": "443",
        "protocol": "https",
        "typesense_api_key": "YOUR_API_KEY",
        "typesense_collection_name": "lang-chain"
    }
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[35], line 15
#      11 # 2. Create embeddings
#      12 embeddings = OpenAIEmbeddings()
#      13
#      14 # 3. Create vector store
# ---> 15 docsearch = Typesense.from_documents(
#      16     docs,
#      17     embeddings,
#      18     typesense_client_params={
#
# File d:\YTRAG\.venv\Lib\site-packages\langchain_core\vectorstores\base.py:814, in VectorStore.from_documents(cls, documents, embedding, **kwargs)
#     811     if any(ids):
#     812         kwargs["ids"] = ids
# --> 814 return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#
# File d:\YTRAG\.venv\Lib\site-packages\langchain_community\vectorstores\typesense.py:277, in Typesense.from_texts(cls, texts, embedding, metadatas, ids, typesense_client, typesense_client_params, typesense_collection_name, text_key, **kwargs)
#     273 else:
#     274     raise ValueError(
#     275         "Must specify one of typesense_client or typesense_client_params."
#     276     )
# --> 277 vectorstore.add_texts(texts, metadatas=metadatas, ids=ids)
#     278 return vectorstore
#
# File d:\YTRAG\.venv\Lib\site-packages\langchain_community\vectorstores\typesense.py:135, in Typesense.add_texts(self, texts, metadatas, ids, **kwargs)
#     122 """Run more texts through the embedding and add to the vectorstore.
#     123
#     124 Args:
#    (...)    131
#     132 """
#     133 from typesense.exceptions import ObjectNotFound
# --> 135 docs = self._prep_texts(texts, metadatas, ids)
#     136 try:
#     137     self._collection.documents.import_(docs, {"action": "upsert"})
#
# File d:\YTRAG\.venv\Lib\site-packages\langchain_community\vectorstores\typesense.py:96, in Typesense._prep_texts(self, texts, metadatas, ids)
#      94 _ids = ids or (str(uuid.uuid4()) for _ in texts)
#      95 _metadatas: Iterable[dict] = metadatas or ({} for _ in texts)
# ---> 96 embedded_texts = self._embedding.embed_documents(list(texts))
#      97 return [
#      98     {"id": _id, "vec": vec, f"{self._text_key}": text, "metadata": metadata}
#      99     for _id, vec, text, metadata in zip(_ids, embedded_texts, texts, _metadatas)
#     100 ]
#
# File d:\YTRAG\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:755, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     752 # Unconditionally call _get_len_safe_embeddings to handle length safety.
#     753 # This could be optimized to avoid double work when all texts are short enough.
#     754 engine = cast(str, self.deployment)
# --> 755 return self._get_len_safe_embeddings(
#     756     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     757 )
#
# File d:\YTRAG\.venv\Lib\site-packages\langchain_openai\embeddings\base.py:622, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     620 # Make API call with this batch
#     621 batch_tokens = tokens[i:batch_end]
# --> 622 response = self.client.create(input=batch_tokens, **client_kwargs)
#     623 if not isinstance(response, dict):
#     624     response = response.model_dump()
#
# File d:\YTRAG\.venv\Lib\site-packages\openai\resources\embeddings.py:136, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     130             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     131                 base64.b64decode(data), dtype="float32"
#     132             ).tolist()
#     134     return obj
# --> 136 return self._post(
#     137     "/embeddings",
#     138     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     139     options=make_request_options(
#     140         extra_headers=extra_headers,
#     141         extra_query=extra_query,
#     142         extra_body=extra_body,
#     143         timeout=timeout,
#     144         post_parser=parser,
#     145         security={"bearer_auth": True},
#     146     ),
#     147     cast_to=CreateEmbeddingResponse,
#     148 )
#
# File d:\YTRAG\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\YTRAG\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
docsearch=Typesense.from_documents(
    docs,
    embeddings,
    typesense_client_params={
        "host": "8a5wnxyt2pmjdoh9p-1.a1.typesense.net",  # Use xxx.a1.typesense.net for Typesense Cloud
        "port": "443",  # Use 443 for Typesense Cloud
        "protocol": "https",  # Use https for Typesense Cloud
        "typesense_api_key":"kfl7rI0OUu4LrE3ZnQrZiiZfhvS1elvM",
        "typesense_collection_name": "lang-chain"
    },
    
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 docsearch=Typesense.from_documents(
# ----> 2     docs,
#       3     embeddings,
#       4     typesense_client_params={
#       5         "host": "8a5wnxyt2pmjdoh9p-1.a1.typesense.net",  # Use xxx.a1.typesense.net for Typesense Cloud
#
# NameError: name 'docs' is not defined

# %%
query = "What is artificial intelligence"
found_docs = docsearch.similarity_search(query)
print(found_docs[0].page_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 query = "What is artificial intelligence"
# ----> 2 found_docs = docsearch.similarity_search(query)
#       3 print(found_docs[0].page_content)
#
# NameError: name 'docsearch' is not defined

# %%
query = "Artificial intelligence indepth explanation"
retriever.invoke(query)[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 query = "Artificial intelligence indepth explanation"
# ----> 2 retriever.invoke(query)[0]
#
# NameError: name 'retriever' is not defined
